# %%
import sys
import os
sys.path.append('Jerome_scripts_Original/PGM/')
sys.path.append('selfPackages/')
sys.path.append('Jerome_scripts_Original/')

import numpy as np
import scipy as sc
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

try:
    import rbm
    import bm
except:
    print 'Compiling cy_utilities first'
    curr_dir = os.getcwd()
    os.chdir('PGM/')
    # !python setup.py build_ext --inplace
    print 'Compilation done'
    os.chdir(curr_dir)
    
import pickle
from ising import IsingModel
import estimate_correlations_ising
from sklearn.utils import shuffle
import inlineMovies

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import norm
from scipy.integrate import odeint
from scipy.optimize import curve_fit
import scipy as sc
import numdifftools as nd

# %%
import dill
dill.dump_session('./data_bruckner/data/notebookData/34_shapeBump-bValue.db')

# %%
import dill
dill.load_session('./data_bruckner/data/notebookData/34_shapeBump-bValue.db')

# %%
n_v = 100
corr_len = 10
integration_time = 500
learning_rate = 0.01

# %%
weights = 0.1*np.random.randn(integration_time+1,n_v)
#print weights

# %% [markdown]
# ## Use my equation:

# %%
def Remi_Moshir(y,t):
    dydt = (np.roll(y,1) + np.roll(y,-1)) + (y**3 - y*np.sum(y**2))
    return dydt

# %%
def Remi_Moshir_cube(y,t,beta):
    dydt = (np.roll(y,1) + np.roll(y,-1)) + (y**3 - y*np.sum(y**2)) - beta*((y**2)*(np.roll(y,1)+np.roll(y,-1)) - (np.roll(y,1)**3 + np.roll(y,-1)**3)/3)
    return dydt

# %%
beta = 0.001
#init_cond = 40*norm.pdf(x=np.linspace(0,99,100),loc=75,scale=5)
init_cond = 1*np.random.randn(n_v)
#init_cond = 1*np.sin(np.linspace(0,99,100)/2)
time_int = np.linspace(0,50000,10000)
sol_remi = odeint(Remi_Moshir,init_cond,time_int)
sol_remi2 = odeint(Remi_Moshir_cube,init_cond,time_int,args=(beta,))

# %%
print(np.sum(init_cond**2))
# Out:
# 86.1748344743

# %%
plt.plot(init_cond)

# %%
plt.plot(sol_remi[-1,:])
plt.plot(sol_remi2[-1,:])

# %% [markdown]
# ## Train RBM with differnet initialzations of w (or of b) to understand the convergance of the solution.

# %%
#%%capture capt1
#Supress the output of the cell and save it to capt1

from scipy.stats import norm

N = 100
beta = 1.
Num_configs = 10000

#Generate spins using Gibbs Sampling MCMC
BM = bm.BM(N=N,nature='Spin')

#Define Couplings
BM.layer.couplings =  beta* (np.eye(N=N,k=1) + np.eye(N=N,k=-1) )
BM.layer.couplings[0,-1] += beta
BM.layer.couplings[-1,0] += beta

data = BM.gen_data(Nchains=1,Nthermalize=0,Lchains=Num_configs,Nstep=200) # N steps.

#Train the model
RBM = rbm.RBM(visible = 'Spin', n_v=N, n_h = 1, hidden = 'Spin',zero_field = True)
#RBM.weights = 0.01*np.random.normal(loc=0,scale=0.1,size=(1,N))
#RBM.weights += 50*norm.pdf(x=np.linspace(0,99,100),loc=70,scale=10)
RBM.weights = np.array([1*np.random.randn(N)])
results = RBM.fit(data,n_iter=100,verbose=0,learning_rate = 0.001,record=['W'],record_interval=100,batch_size=10,N_MC= 20,lr_decay=False,batch_norm=False,init='previous')
# Out:
# Starting epoch 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-c9f19d9b75db> in <module>()
#      23 #RBM.weights += 50*norm.pdf(x=np.linspace(0,99,100),loc=70,scale=10)
#      24 RBM.weights = [1*np.random.randn(N)]
# ---> 25 results = RBM.fit(data,n_iter=100,verbose=0,learning_rate = 0.001,record=['W'],record_interval=100,batch_size=10,N_MC= 20,lr_decay=False,batch_norm=False,init='previous')
#
# /users/harsh/Work/learningDynamics/Jerome_scripts_Original/PGM/rbm.pyc in fit(self, data, batch_size, learning_rate, extra_params, init, optimizer, batch_norm, CD, N_PT, N_MC, nchains, n_iter, lr_decay, lr_final, decay_after, l1, l1b, l1c, l2, l2_fields, no_fields, weights, update_betas, record_acceptance, shuffle_data, epsilon, verbose, record, record_interval, data_test, weights_test, l1_custom, l1b_custom, M_AIS, n_betas_AIS)
#     485             for batch_slice in batch_slices:
#     486                 if weights is None:
# --> 487                     self.minibatch_fit(data[batch_slice],weights=None)
#     488                 else:
#     489                     self.minibatch_fit(data[batch_slice],weights=weights[batch_slice])
#
# /users/harsh/Work/learningDynamics/Jerome_scripts_Original/PGM/rbm.pyc in minibatch_fit(self, V_pos, weights)
#     587
#     588             else:
# --> 589                 (self.fantasy_v,self.fantasy_h) = self.markov_step((self.fantasy_v,self.fantasy_h) )
#     590
#     591         if self.N_PT>1:
#
# /users/harsh/Work/learningDynamics/Jerome_scripts_Original/PGM/rbm.pyc in markov_step(self, (v, h), beta)
#     132
#     133     def markov_step(self,(v,h),beta =1):
# --> 134          h = self.hlayer.sample_from_inputs( self.vlayer.compute_output(v,self.weights, direction ='up') , beta = beta )
#     135          v = self.vlayer.sample_from_inputs( self.hlayer.compute_output(h,self.weights,direction='down') , beta = beta )
#     136          return (v,h)
#
# /users/harsh/Work/learningDynamics/Jerome_scripts_Original/PGM/layer.pyc in compute_output(self, config, couplings, direction)
#     670
#     671         if direction == 'up':
# --> 672             N_output_layer = couplings.shape[0]
#     673             if self.nature in ['Potts','Potts_coupled']:
#     674                 if couplings.ndim == 4: # output layer is Potts
#
# AttributeError: 'list' object has no attribute 'shape'
