# %% [markdown]
# # Geneate Configurations of 1D XY model and train RBM on that.
#
# ### Its not easy to generate the samples from XY model - we discretize the angles and use potts model instaed.

# %%
import sys
import os
sys.path.append('Jerome_scripts_Original/PGM/')
sys.path.append('selfPackages/')
sys.path.append('Jerome_scripts_Original/')
sys.path.append('ffmpeg-3.4.2-32bit-static/')

import numpy as np
import scipy as sc
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

try:
    import rbm
    import bm
except:
    print 'Compiling cy_utilities first'
    curr_dir = os.getcwd()
    os.chdir('PGM/')
    # !python setup.py build_ext --inplace
    print 'Compilation done'
    os.chdir(curr_dir)
    
import pickle
from ising import IsingModel
import estimate_correlations_ising
from sklearn.utils import shuffle
import inlineMovies

# %%
#import dill
#dill.dump_session('./data_bruckner/data/notebookData/23_XYmodel_1D_Bernoulli')

# %%
import dill
dill.load_session('./data_bruckner/data/notebookData/23_XYmodel_1D_Bernoulli')

# %%
# Save the data array with the 1d XY model configurations: Expensive to generate over again.
#np.save('./data_bruckner/data/notebookData/data_XY1D_100000_beta1.5_size100_states=10',data)
#data = np.load('./data_bruckner/data/notebookData/data_XY1D_100000_beta1.5_size100_states=10.npy')

# %%
#%%capture capt1
#Supress the output of the cell and save it to capt1

size = 100
N = size
beta = 1.5
Num_configs = 100000

#Generate spins using Gibbs Sampling MCMC
BM = bm.BM(N=N,nature='Potts',n_c=10)

#Define Couplings
BM.layer.couplings = XY1dCouplings(BM,size = 100,beta=beta,num_states=10,PBC=True)

data = BM.gen_data(Nchains=1,Nthermalize=0,Lchains=Num_configs,Nstep=200) # N steps.

#Estimate Correlations for number of MC steps
plt.plot(data.mean(1)[0:10000]);plt.show()

#import estimate_correlations_ising
#Xcorr = estimate_correlations_ising.spin_autocorr(data,n_max=int(Num_configs*0.1))
#plt.plot(Xcorr);plt.show()

# %%
plt.figure(figsize=(10,6))
plt.imshow(data[0:100],aspect='auto',cmap='spectral')
plt.colorbar()

# %%
plt.figure(figsize=(10,6))
plt.imshow(data[0:100],aspect='auto',cmap='spectral')
plt.colorbar()
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# /users/harsh/anaconda2/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.hist(np.ndarray.flatten(data),100)
plt.xlabel('Potts Index')
plt.ylabel('Counts')
plt.title('Distribution of Potts Index')
# Out:
# Text(0.5,1,u'Distribution of Potts Index')

# %%
plt.hist(np.ndarray.flatten(data),100);plt.show()

# %%
def XY1dCouplings(BM,size=100,beta=1.0,num_states=10,PBC=False):
    
    # This is only the nearest neighbour interactions XY model on a 1D lattcie
    pottsCouplings = np.zeros([num_states,num_states])
    
    for i in np.arange(0,num_states):
        for j in np.arange(0,num_states):
            pottsCouplings[i,j] = np.cos((i-j)*2*np.pi/num_states)
        
    BM.layer.couplings[(np.eye(N=size,k=-1)+np.eye(N=size,k=+1)).astype(bool),:,:] = beta*pottsCouplings
    
    if PBC is True:
        BM.layer.couplings[0,-1] = beta*pottsCouplings
        BM.layer.couplings[-1,0] = beta*pottsCouplings
    
    return BM.layer.couplings

# %%
def XY2dCouplings(BM,size=20,beta1=1.0,beta2=1.0,num_states=10,PBC=False):
    
    # This is only the nearest neighbour XY model on a 2D square lattice
    # Calculate the KT transition beta
        
    pottsCouplings = np.zeros([num_states,num_states])
    N = size
    
    for i in np.arange(0,num_states):
        for j in np.arange(0,num_states):
            pottsCouplings[i,j] = np.cos((i-j)*2*np.pi/num_states)
            
    BM.layer.couplings[(np.eye(N=size**2,k=1) + np.eye(N=size**2,k=-1)).astype(bool),:,:] =  beta1*pottsCouplings
    BM.layer.couplings[(np.eye(N=size**2,k=size) + np.eye(N=size**2,k=-size)).astype(bool),:,:] =  beta2*pottsCouplings
    
    # Remove the couplings of the left most coloumn to that of the last coloumn in its previous row:
    for i in np.arange(0,N*N,N):
        BM.layer.couplings[i,i-1] = 0
        BM.layer.couplings[i-1,i] = 0
    
    if PBC is True:
        # Add the couplings of the first row to that of the last row and vice versa:
        for i in np.arange(0,N):
            BM.layer.couplings[i,(size**2)-N+i] = beta2*pottsCouplings
            BM.layer.couplings[(size**2)-N+i,i] = beta2*pottsCouplings
        # Add the couplings of the left most column to the right most coloumn:
            BM.layer.couplings[i,i+N-1] = beta1*pottsCouplings
            BM.layer.couplings[i+N-1,i] = beta1*pottsCouplings
    
    return BM.layer.couplings

# %%
#Train the model
RBM = rbm.RBM(visible = 'Potts', n_cv=10, n_v=N, n_h = 1, hidden = 'Bernoulli',zero_field = True)
results = RBM.fit(data,n_iter=100,verbose=0,learning_rate = 0.01,record=['W'],record_interval=100,batch_size=100,N_MC= 20, lr_decay=False,batch_norm=False);
# Out:
# Starting epoch 1
# Starting epoch 2
# Starting epoch 3
# Starting epoch 4
# Starting epoch 5
# Starting epoch 6
# Starting epoch 7
# Starting epoch 8
# Starting epoch 9
# Starting epoch 10
# Starting epoch 11
# Starting epoch 12
# Starting epoch 13
# Starting epoch 14
# Starting epoch 15
# Starting epoch 16
# Starting epoch 17
# Starting epoch 18
# Starting epoch 19
# Starting epoch 20
# Starting epoch 21
# Starting epoch 22
# Starting epoch 23
# Starting epoch 24
# Starting epoch 25
# Starting epoch 26
# Starting epoch 27
# Starting epoch 28
# Starting epoch 29
# Starting epoch 30
# Starting epoch 31
# Starting epoch 32
# Starting epoch 33
# Starting epoch 34
# Starting epoch 35
# Starting epoch 36
# Starting epoch 37
# Starting epoch 38
# Starting epoch 39
# Starting epoch 40
# Starting epoch 41
# Starting epoch 42
# Starting epoch 43
# Starting epoch 44
# Starting epoch 45
# Starting epoch 46
# Starting epoch 47
# Starting epoch 48
# Starting epoch 49
# Starting epoch 50
# Starting epoch 51
# Starting epoch 52
# Starting epoch 53
# Starting epoch 54
# Starting epoch 55
# Starting epoch 56
# Starting epoch 57
# Starting epoch 58
# Starting epoch 59
# Starting epoch 60
# Starting epoch 61
# Starting epoch 62
# Starting epoch 63
# Starting epoch 64
# Starting epoch 65
# Starting epoch 66
# Starting epoch 67
# Starting epoch 68
# Starting epoch 69
# Starting epoch 70
# Starting epoch 71
# Starting epoch 72
# Starting epoch 73
# Starting epoch 74
# Starting epoch 75
# Starting epoch 76
# Starting epoch 77
# Starting epoch 78
# Starting epoch 79
# Starting epoch 80
# Starting epoch 81
# Starting epoch 82
# Starting epoch 83
# Starting epoch 84
# Starting epoch 85
# Starting epoch 86
# Starting epoch 87
# Starting epoch 88
# Starting epoch 89
# Starting epoch 90
# Starting epoch 91
# Starting epoch 92
# Starting epoch 93
# Starting epoch 94
# Starting epoch 96
# Starting epoch 97
# Starting epoch 98
# Starting epoch 99
# Starting epoch 100

# %%
print np.shape(data)
# Out:
# (100000, 100)

# %%
np.shape(np.array(results['W']))
# Out:
# (1000, 1, 100, 10)

# %%
plt.figure(figsize=(15,6))
plt.imshow(np.array(results['W'])[-1,0,:,:].T,aspect=5)
plt.colorbar()

# %%
plt.figure(figsize=(15,6))
plt.contourf(np.array(results['W'])[-1,0,:,:].T,aspect='auto')
plt.colorbar()

# %%
plt.figure(figsize=(20,10))
plt.contourf(np.array(results['W'])[-1,0,:,:].T)
plt.colorbar()
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('Visible Unit Index',fontsize=18)
plt.ylabel('Potts State (or XY angle)',fontsize=18)
plt.title('Contour Plot of RBM weights trained on XY model discretized using 10 Potts State, Bernaulli hidden units',fontsize=18)
# Out:
# Text(0.5,1,u'Contour Plot of RBM weights trained on XY model discretized using 10 Potts State, Bernaulli hidden units')

# %%
plt.figure(figsize=(20,10))
plt.contourf(np.array(results['W'])[-1,0,:,:].T)
cbar = plt.colorbar()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Visible Unit Index',fontsize=28)
plt.ylabel('Potts State (or XY angle)',fontsize=28)
cbar.ax.tick_params(labelsize=20)
#plt.title('Contour Plot of RBM weights trained on XY model discretized using 10 Potts State, Bernaulli hidden units',fontsize=18)

# %%
# plot the arrows for the learnt matrix:
num_states=10
plt.figure(figsize=(20,20))
plt.xlim(-0.5,9.5)
plt.ylim(-0.5,9.5)
for i in np.arange(np.shape(np.array(results['W']))[2]):
    for j in np.arange(np.shape(np.array(results['W']))[3]):
        plt.arrow(x=i%10,\
                  y=i/10,\
                  dx=3*np.array(results['W'])[-1,0,i,j]*np.cos(j*2*np.pi/num_states),\
                  dy=3*np.array(results['W'])[-1,0,i,j]*np.sin(j*2*np.pi/num_states),\
                 shape='full',length_includes_head=True,head_starts_at_zero=True)

plt.show()

# %%
plt.scatter(np.arange(10),np.sum((np.array(results['W'])[-1,0,:,:]),axis=0))

# %%
plt.scatter(np.arange(10),np.sum(abs(np.array(results['W'])[-1,0,:,:]),axis=0))

# %%
plt.plot(np.sum(abs(np.array(results['W'])[-1,0,:,:]),axis=1),'o')

# %%
np.argmax(np.sum(abs(np.array(results['W'])[-1,0,:,:]),axis=1))
# Out:
# 58

# %%
plt.plot(np.arange(10),(np.array(results['W'])[-1,0,58,:]),'o-')

# %%
def cosfit(x,peak,phase,freq):
    return peak*np.cos(x*freq + phase)

popt = np.zeros([len(np.array(results['W'])[:,0,0,0]),len(np.array(results['W'])[-1,0,:,0]),3])
popc = np.zeros([len(np.array(results['W'])[:,0,0,0]),len(np.array(results['W'])[-1,0,:,0]),3,3])

for i in np.arange(len(np.array(results['W'])[-1,0,:,0])):
    for j in np.arange(len(np.array(results['W'])[:,0,0,0])):
        try:
            popt[j,i],popc[j,i] = sc.optimize.curve_fit(cosfit,np.arange(10),(np.array(results['W'])[j,0,i,:]),[1,1,2*np.pi/10],bounds=(0,[np.inf,2*np.pi,np.inf]))
        except:
            pass

# %%
plt.scatter(np.arange(10),(np.array(results['W'])[-1,0,58,:]))
plt.plot(np.arange(0,10,.1),cosfit(np.arange(0,10,.1),*popt[-1,58]))

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(popt[-1,:,0],'o-')
plt.title('Peak')
plt.subplot(122)
plt.hist(np.ndarray.flatten(popt[:,:,0]),40,(-0.5,0.5));plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(popt[-1,:,1],'o-')
plt.title('Phase')
plt.subplot(122)
plt.hist(np.ndarray.flatten(popt[:,:,1]),40,(-2.5,6));plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(popt[-1,:,2],'o-')
plt.plot(np.ones(100)*2*np.pi/10)
plt.title('Frequency')
plt.subplot(122)
plt.hist(np.ndarray.flatten(popt[:,:,2]),40,(0.4,2));plt.show()

# %% [markdown]
# ### Time evolution of the quantities at the location of argmax of the abs sum of weight vector at each time

# %%
plt.figure(figsize=(20,4))
plt.plot(np.argmax(np.sum(abs(np.array(results['W'])[:,0,:,:]),axis=2),axis=1),'o')
plt.ylim((0,100))
# Out:
# (0, 100)

# %%
k = 0
plt.figure(figsize=(20,4))
for i in (np.argmax(np.sum(abs(np.array(results['W'])[:,0,:,:]),axis=2),axis=1)):
    plt.scatter(k,popt[k,i,1],c='b')
    k+=1

# %% [markdown]
# ### Time evolution of the quantities from the max of the histogram at each time:

# %%
hist_poptMax = np.zeros([len(np.array(results['W'])[:,0,0,0]),3]) 
for i in np.arange(len(np.array(results['W'])[:,0,0,0])):
    for j in range(3):
        t1,t2 = np.histogram(popt[i,:,j],40);
        hist_poptMax[i,j] = (t2[np.argmax(t1)]+t2[np.argmax(t1)+1])/2
    
del t1,t2

# %%
plt.figure(figsize=(20,4))
plt.plot(hist_poptMax[:,1],'o')

# %%
plt.figure(figsize=(20,4))
plt.plot(hist_poptMax[:,2],'o')

# %% [markdown]
# ### Time evolution of the quantities averaged over locations in the neighbourhood of the correct frequency at each time

# %%
num_states = 10
freq_tolearnce = 0.2
freq_correct = 2*np.pi/num_states
freq_popt = np.zeros([len(np.array(results['W'])[:,0,0,0]),3])

for i in np.arange(len(np.array(results['W'])[:,0,0,0])):
    freq_popt[i,1] = np.average(popt[i,np.argwhere(np.logical_and(freq_correct*(1-freq_tolearnce)<popt[0,:,2], popt[0,:,2]>freq_correct*(1+freq_tolearnce))),1])
    freq_popt[i,2] = np.average(popt[i,np.argwhere(np.logical_and(freq_correct*(1-freq_tolearnce)<popt[0,:,2], popt[0,:,2]>freq_correct*(1+freq_tolearnce))),2])
    freq_popt[i,0] = np.average(popt[i,np.argwhere(np.logical_and(freq_correct*(1-freq_tolearnce)<popt[0,:,2], popt[0,:,2]>freq_correct*(1+freq_tolearnce))),0])

# %%
plt.figure(figsize=(20,4))
plt.plot(freq_popt[:,1],'o')

# %% [markdown]
# ## ReLU Hidden Units:

# %%
#Train the model
import rbm_relu
RBM2 = rbm_relu.RBM(visible = 'Potts', n_cv=10, n_v=N, n_h = 1, hidden = 'ReLU',zero_field = False)
results2 = RBM2.fit(data,n_iter=100,verbose=0,learning_rate = 0.1,record=['W'],record_interval=100,batch_size=100,N_MC= 20, lr_decay=False,batch_norm=False);
# Out:
# Starting epoch 1
# Jerome_scripts_Original/PGM/layer.py:315: RuntimeWarning: invalid value encountered in sqrt
#   etg_plus = erf_times_gauss((-beta*psi + (beta*self.theta_plus + (1-beta) * self.theta_plus0)[np.newaxis,:])/np.sqrt( beta*self.a + (1-beta)* self.a0)[np.newaxis,:])
# Jerome_scripts_Original/PGM/layer.py:316: RuntimeWarning: invalid value encountered in sqrt
#   etg_minus = erf_times_gauss((beta*psi + (beta*self.theta_minus+(1-beta) * self.theta_minus0)[np.newaxis,:])/np.sqrt( beta*self.a + (1-beta)* self.a0)[np.newaxis,:])
# Jerome_scripts_Original/PGM/layer.py:319: RuntimeWarning: invalid value encountered in sqrt
#   mean_neg = (beta*psi + (beta*self.theta_minus + (1-beta) * self.theta_minus0)[np.newaxis,:])/(beta*self.a+(1-beta)*self.a0)[np.newaxis,:] - 1/etg_minus/np.sqrt( beta*self.a + (1-beta)* self.a0)[np.newaxis,:]
# Jerome_scripts_Original/PGM/layer.py:320: RuntimeWarning: invalid value encountered in sqrt
#   mean_pos = (beta*psi - (beta*self.theta_plus+(1-beta) * self.theta_plus0)[np.newaxis,:])/(beta*self.a+(1-beta)*self.a0)[np.newaxis,:] + 1/etg_plus/np.sqrt( beta*self.a + (1-beta)* self.a0)[np.newaxis,:]
# Jerome_scripts_Original/PGM/layer.py:251: RuntimeWarning: invalid value encountered in sqrt
#   etg_plus = erf_times_gauss((-beta*psi + (beta*self.theta_plus + (1-beta) * self.theta_plus0)[np.newaxis,:])/np.sqrt( beta*self.a + (1-beta)* self.a0)[np.newaxis,:])
# Jerome_scripts_Original/PGM/layer.py:252: RuntimeWarning: invalid value encountered in sqrt
#   etg_minus = erf_times_gauss((beta*psi + (beta*self.theta_minus+(1-beta) * self.theta_minus0)[np.newaxis,:])/np.sqrt( beta*self.a + (1-beta)* self.a0)[np.newaxis,:])
# Jerome_scripts_Original/PGM/layer.py:255: RuntimeWarning: invalid value encountered in sqrt
#   mean2_pos = 1/(beta*self.a+(1-beta)*self.a0)[np.newaxis,:] * (1 +     ((beta*psi - (beta*self.theta_plus+(1-beta)*self.theta_plus0)[np.newaxis,:])/np.sqrt(beta*self.a+(1-beta)*self.a0)[np.newaxis,:])**2  -  ((-psi + (beta*self.theta_plus+(1-beta)*self.theta_plus0)[np.newaxis,:])/np.sqrt(beta*self.a+(1-beta)*self.a0)[np.newaxis,:])/etg_plus )
# Jerome_scripts_Original/PGM/layer.py:256: RuntimeWarning: invalid value encountered in sqrt
#   mean2_neg = 1/(beta*self.a+(1-beta)*self.a0)[np.newaxis,:] * (1 +     ((beta*psi + (beta*self.theta_minus+(1-beta)*self.theta_minus0)[np.newaxis,:])/np.sqrt(beta*self.a+(1-beta)*self.a0)[np.newaxis,:])**2  -  ((psi + (beta*self.theta_minus+(1-beta)*self.theta_minus0)[np.newaxis,:])/np.sqrt(beta*self.a+(1-beta)*self.a0)[np.newaxis,:])/etg_minus )
# Starting epoch 2
# Starting epoch 3
# Starting epoch 4
# Starting epoch 5
# Starting epoch 6
# Starting epoch 7
# Starting epoch 8
# Starting epoch 9
# Starting epoch 10
# Starting epoch 11
# Starting epoch 12
# Starting epoch 13
# Starting epoch 14
# Starting epoch 15
# Starting epoch 16
# Starting epoch 17
# Starting epoch 18
# Starting epoch 19
# Starting epoch 20
# Starting epoch 21
# Starting epoch 22
# Starting epoch 23
# Starting epoch 24
# Starting epoch 25
# Starting epoch 26
# Starting epoch 27
# Starting epoch 28
# Starting epoch 29
# Starting epoch 30
# Starting epoch 31
# Starting epoch 32
# Starting epoch 33
# Starting epoch 34
# Starting epoch 35
# Starting epoch 36
# Starting epoch 37
# Starting epoch 38
# Starting epoch 39
# Starting epoch 40
# Starting epoch 41
# Starting epoch 42
# Starting epoch 43
# Starting epoch 44
# Starting epoch 45
# Starting epoch 46
# Starting epoch 47
# Starting epoch 48
# Starting epoch 49
# Starting epoch 50
# Starting epoch 51
# Starting epoch 52
# Starting epoch 53
# Starting epoch 54
# Starting epoch 55
# Starting epoch 56
# Starting epoch 57
# Starting epoch 58
# Starting epoch 59
# Starting epoch 60
# Starting epoch 61
# Starting epoch 62
# Starting epoch 63

# %%
plt.figure(figsize=(15,6))
plt.imshow(np.array(results2['W'])[-1,0,:,:].T,aspect=5)
plt.colorbar()

# %%
plt.figure(figsize=(15,6))
plt.contourf(np.array(results2['W'])[-1,0,:,:].T,aspect='auto')
plt.colorbar()

# %%
plt.figure(figsize=(20,10))
plt.contourf(np.array(results2['W'])[-1,0,:,:].T)
plt.colorbar()
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel('Visible Unit Index',fontsize=18)
plt.ylabel('Potts State (or XY angle)',fontsize=18)
plt.title('Contour Plot of RBM weights trained on XY model discretized using 10 Potts State, ReLU hidden units',fontsize=18)
# Out:
# Text(0.5,1,u'Contour Plot of RBM weights trained on XY model discretized using 10 Potts State, ReLU hidden units')

# %%
plt.figure(figsize=(20,10))
plt.contourf(np.array(results2['W'])[-1,0,:,:].T)
cbar = plt.colorbar()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Visible Unit Index',fontsize=28)
plt.ylabel('Potts State (or XY angle)',fontsize=28)
cbar.ax.tick_params(labelsize=20)
#plt.title('Contour Plot of RBM weights trained on XY model discretized using 10 Potts State, ReLU hidden units',fontsize=18)
# Out:
# Text(0,0.5,u'Potts State (or XY angle)')

# %%
# plot the arrows for the learnt matrix:
num_states=10
plt.figure(figsize=(20,20))
plt.xlim(-0.5,9.5)
plt.ylim(-0.5,9.5)
for i in np.arange(np.shape(np.array(results2['W']))[2]):
    for j in np.arange(np.shape(np.array(results2['W']))[3]):
        plt.arrow(x=i%10,\
                  y=i/10,\
                  dx=3*np.array(results2['W'])[-1,0,i,j]*np.cos(j*2*np.pi/num_states),\
                  dy=3*np.array(results2['W'])[-1,0,i,j]*np.sin(j*2*np.pi/num_states),\
                 shape='full',length_includes_head=True,head_starts_at_zero=True)

plt.show()

# %%
plt.scatter(np.arange(10),np.sum((np.array(results2['W'])[-1,0,:,:]),axis=0))

# %%
plt.scatter(np.arange(10),np.sum(abs(np.array(results2['W'])[-1,0,:,:]),axis=0))

# %%
plt.plot(np.sum(abs(np.array(results2['W'])[-1,0,:,:]),axis=1),'o')
plt.xlabel('Visible Unit Index')
plt.ylabel('Absolute sum of the weight vector')
# Out:
# Text(0,0.5,u'Absolute sum of the weight vector')

# %%
np.argmax(np.sum(abs(np.array(results2['W'])[-1,0,:,:]),axis=1))
# Out:
# 39

# %%
plt.plot(np.arange(10),(np.array(results2['W'])[-1,0,39,:]),'o-')

# %%
def cosfit(x,peak,phase,freq):
    return peak*np.cos(x*freq + phase)

popt2 = np.zeros([len(np.array(results2['W'])[:,0,0,0]),len(np.array(results2['W'])[-1,0,:,0]),3])
popc2 = np.zeros([len(np.array(results2['W'])[:,0,0,0]),len(np.array(results2['W'])[-1,0,:,0]),3,3])

for i in np.arange(len(np.array(results2['W'])[-1,0,:,0])):
    for j in np.arange(len(np.array(results2['W'])[:,0,0,0])):
        try:
            popt2[j,i],popc2[j,i] = sc.optimize.curve_fit(cosfit,np.arange(10),(np.array(results2['W'])[j,0,i,:]),[1,1,2*np.pi/10])
        except:
            pass

# %%
plt.scatter(np.arange(10),(np.array(results2['W'])[-1,0,39,:]))
plt.plot(np.arange(0,10,.1),cosfit(np.arange(0,10,.1),*popt2[-1,39]))
plt.xlabel('Potts State')
plt.ylabel('Weight vector at of maximum sum of weights')
# Out:
# Text(0,0.5,u'Weight vector at of maximum sum of weights')

# %%
popt2[-1,39]
# Out:
# array([ 1.00001196,  0.76487532,  0.63837347])

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(popt2[-1,:,0],'o-')
plt.title('Peak')
plt.subplot(122)
plt.hist(np.ndarray.flatten(popt2[:,:,0]),39);plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(popt2[-1,:,1],'o-')
plt.title('Phase')
plt.subplot(122)
plt.hist(np.ndarray.flatten(popt2[:,:,1]),39);plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(popt2[-1,:,1]/(2*np.pi),'o-')
plt.xlabel('Visible unit index',fontsize=16)
plt.hlines(0.765/(2*np.pi),-5,105,linestyle='--',alpha=0.5)
plt.rc('text', usetex=True)
plt.rc('font', family='serif',size=14)
plt.text(-5,1./(2*np.pi),str(np.round(0.765/(2*np.pi),3)),alpha=0.8)
plt.ylabel('Phase (multiples of 2\pi)',fontsize=16)

plt.subplot(122)
plt.plot(popt2[-1,:,2]/(2*np.pi),'o-')
plt.hlines(1./10,-5,105,linestyle='--',alpha=0.5)
plt.rc('text', usetex=True)
plt.rc('font', family='serif',size=14)
plt.text(-5,0.08,'1/10',alpha=0.8)
plt.ylabel('Frequency (multiples of 2\pi)',fontsize=16)
plt.xlabel('Visible unit index',fontsize=16)
# Out:
# Text(0.5,0,u'Visible unit index')

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(popt2[-1,:,2],'o-')
plt.plot(np.ones(100)*2*np.pi/10)
plt.title('Frequency')
plt.subplot(122)
plt.hist(np.ndarray.flatten(popt2[:,:,2]),39);plt.show()

# %% [markdown]
# ### Time evolution of the quantities

# %%
plt.figure(figsize=(20,4))
plt.plot(np.argmax(np.sum(abs(np.array(results2['W'])[:,0,:,:]),axis=2),axis=1),'o')
plt.ylim((0,100))
# Out:
# (0, 100)

# %%
k = 0
plt.figure(figsize=(20,4))
for i in (np.argmax(np.sum(abs(np.array(results2['W'])[:,0,:,:]),axis=2),axis=1)):
    plt.scatter(k,popt[k,i,1],c='b')
    k+=1

# %%
# Top Eignvectors of the C_ij matrix:
def topEV(data,method='Covariance'):
    if method is 'Covariance':
        #Find the covariance matrix:
        covMAT = np.cov(data)
    elif method is 'Correlation':
        covMAT = np.corrcoef(data)
    Eval,Evec = np.linalg.eig(covMAT)
    return Evec[:,np.argmax(Eval)],np.max(Eval)

# %%
def ising2dCouplings(BM,size=20,beta1=0.39,beta2=0.39,PBC=False):
    
    BM.layer.couplings =  beta1*(np.eye(N=size**2,k=1) + np.eye(N=size**2,k=-1)) + beta2*(np.eye(N=size**2,k=size) + np.eye(N=size**2,k=-size))
    
    N = size
    
    if PBC is True:
        # Add the couplings of the first row to that of the last row and vice versa:
        for i in np.arange(0,N):
            BM.layer.couplings[i,(size**2)-N+i] = beta2
            BM.layer.couplings[(size**2)-N+i,i] = beta2
        # Remove the couplings of the left most coloumn to that of the last coloumn in its previous row:
        for i in np.arange(0,N*N,N):
            BM.layer.couplings[i,i-1] = 0
            BM.layer.couplings[i-1,i] = 0
        # Add the couplings of the left most column to the right most coloumn:
            BM.layer.couplings[i,i+N-1] = beta1
            BM.layer.couplings[i+N-1,i] = beta1
    
    return BM.layer.couplings
